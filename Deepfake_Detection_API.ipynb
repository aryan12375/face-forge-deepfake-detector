# %% [markdown]
# <a href="https://colab.research.google.com/github/aryan12375/face-forge-deepfake-detector/blob/main/Deepfake_Detection_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Clone the Deepfake project
# !git clone https://github.com/aryan12375/face-forge-deepfake-detector.git
# %cd face-forge-deepfake-detector/deepfake-backend

# 2. Install dependencies (Torch, OpenCV, etc.)
# !pip install -r requirements.txt
# !npm install -g localtunnel

print("\n✅ Environment Ready!")
# Out:
# Cloning into 'face-forge-deepfake-detector'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 74 (delta 3), reused 64 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (74/74), 15.27 MiB | 20.69 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# /content/face-forge-deepfake-detector/deepfake-backend
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 753.8 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 93.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 78.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 97.3 MB/s eta 0:00:00
# ...

# %%
# %cd /content/face-forge-deepfake-detector/deepfake-backend
# Out:
# /content/face-forge-deepfake-detector/deepfake-backend

# %%
import urllib
# 1. Get the tunnel password
print("Tunnel Password:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip())

# 2. Run the FastAPI server in the background
# We use port 8000 as defined in your run.py
# !python run.py & npx localtunnel --port 8000
# Out:
# Tunnel Password: 8.228.18.78
# INFO:     Will watch for changes in these directories: ['/content/face-forge-deepfake-detector/deepfake-backend']
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [2630] using WatchFiles
# ⠙⠹⠸⠼⠴⠦⠧INFO:     Started server process [2644]
# INFO:     Waiting for application startup.
# 2026-05-11 15:45:55,346 | INFO | app.main | Loading EfficientNet-B4 + GradCAM model...
# 2026-05-11 15:45:55,348 | INFO | app.services.model_service | Using device: cpu
# Downloading: "https://download.pytorch.org/models/efficientnet_b4_rwightman-23ab8bcd.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b4_rwightman-23ab8bcd.pth
# 100% 74.5M/74.5M [00:00<00:00, 94.9MB/s]
# ...
